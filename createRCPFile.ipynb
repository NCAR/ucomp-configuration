# %%
import datetime
import numpy as np

# %%
centerList= [637.40,670.16, 706.20,789.40,761.10, 802.41 ,991.26, 1074.70,1079.80	]

# %%
centralWave = 991.26
stepSize = 0.05
waveSteps = 19
cont = "BOTH"
numsums = 16
repeats = 4
exposureTime = 80
LCVRrelaxation = 300
modulations = 4
seconds = 1/1000
cameras =2 

now = datetime.datetime.strftime(datetime.datetime.now(),"%a %b %d %H:%M:%S %Y")
executionTime = (LCVRrelaxation+exposureTime*modulations*numsums)*waveSteps*repeats*cameras*seconds

# %%
print(f"{np.floor(centralWave):.0f}_{str(waveSteps).zfill(2)}wave_{stepSize}step_2beam_{numsums}sums_{repeats}reps_{cont}.rcp")
with open(f"scripts\\{np.floor(centralWave):.0f}_{str(waveSteps).zfill(2)}wave_{stepSize}step_2beam_{numsums}sums_{repeats}reps_{cont}.rcp","w") as f:
    f.write(f"DATE {now}\n")
    f.write(f"AUTHOR: rcp Generator")
    f.write(f"Expected execution time {executionTime:.1f}\n")
    f.write(f"#DATATYPE BEAM  WAVELENGTH  NUMSUMS\n")
    for repeat in range(repeats):
        for cam in ["RCAM","TCAM"]:
            for i in range(waveSteps):
                f.write(f"DATA {cam}\t{((i-np.floor(waveSteps/2))*stepSize)+centralWave:.3f}\t{cont}\t{numsums}\n")
            f.write("\n")
# Out:
# 991_19wave_0.05step_2beam_16sums_4reps_BOTH.rcp

# %%
for repeat in range(repeats):
    for cam in ["RCAM","TCAM"]:
        for i in range(waveSteps):
            print(f"DATA {cam}\t{((i-np.floor(waveSteps/2))*stepSize)+centralWave:.3f}\t{cont}\t{numsums}\n")
        print("\n")
# Out:
# DATA RCAM	990.810	BOTH	16
#
# DATA RCAM	990.860	BOTH	16
#
# DATA RCAM	990.910	BOTH	16
#
# DATA RCAM	990.960	BOTH	16
#
# DATA RCAM	991.010	BOTH	16
#
# DATA RCAM	991.060	BOTH	16
#
# DATA RCAM	991.110	BOTH	16
#
# DATA RCAM	991.160	BOTH	16
#
# DATA RCAM	991.210	BOTH	16
#
# DATA RCAM	991.260	BOTH	16
#
# DATA RCAM	991.310	BOTH	16
#
# DATA RCAM	991.360	BOTH	16
#
# DATA RCAM	991.410	BOTH	16
#
# DATA RCAM	991.460	BOTH	16
#
# DATA RCAM	991.510	BOTH	16
#
# DATA RCAM	991.560	BOTH	16
#
# DATA RCAM	991.610	BOTH	16
#
# DATA RCAM	991.660	BOTH	16
#
# DATA RCAM	991.710	BOTH	16
#
#
#
# DATA TCAM	990.810	BOTH	16
#
# DATA TCAM	990.860	BOTH	16
#
# DATA TCAM	990.910	BOTH	16
#
# DATA TCAM	990.960	BOTH	16
#
# DATA TCAM	991.010	BOTH	16
#
# DATA TCAM	991.060	BOTH	16
#
# DATA TCAM	991.110	BOTH	16
#
# DATA TCAM	991.160	BOTH	16
#
# DATA TCAM	991.210	BOTH	16
#
# DATA TCAM	991.260	BOTH	16
#
# DATA TCAM	991.310	BOTH	16
#
# DATA TCAM	991.360	BOTH	16
#
# DATA TCAM	991.410	BOTH	16
#
# DATA TCAM	991.460	BOTH	16
#
# DATA TCAM	991.510	BOTH	16
#
# DATA TCAM	991.560	BOTH	16
#
# DATA TCAM	991.610	BOTH	16
#
# DATA TCAM	991.660	BOTH	16
#
# DATA TCAM	991.710	BOTH	16
#
#
#
# DATA RCAM	990.810	BOTH	16
#
# DATA RCAM	990.860	BOTH	16
#
# DATA RCAM	990.910	BOTH	16
#
# DATA RCAM	990.960	BOTH	16
#
# DATA RCAM	991.010	BOTH	16
#
# DATA RCAM	991.060	BOTH	16
#
# DATA RCAM	991.110	BOTH	16
#
# DATA RCAM	991.160	BOTH	16
#
# DATA RCAM	991.210	BOTH	16
#
# DATA RCAM	991.260	BOTH	16
#
# DATA RCAM	991.310	BOTH	16
#
# DATA RCAM	991.360	BOTH	16
#
# DATA RCAM	991.410	BOTH	16
#
# DATA RCAM	991.460	BOTH	16
#
# DATA RCAM	991.510	BOTH	16
#
# DATA RCAM	991.560	BOTH	16
#
# DATA RCAM	991.610	BOTH	16
#
# DATA RCAM	991.660	BOTH	16
#
# DATA RCAM	991.710	BOTH	16
#
#
#
# DATA TCAM	990.810	BOTH	16
#
# DATA TCAM	990.860	BOTH	16
#
# DATA TCAM	990.910	BOTH	16
#
# DATA TCAM	990.960	BOTH	16
#
# DATA TCAM	991.010	BOTH	16
#
# DATA TCAM	991.060	BOTH	16
#
# DATA TCAM	991.110	BOTH	16
#
# DATA TCAM	991.160	BOTH	16
#
# DATA TCAM	991.210	BOTH	16
#
# DATA TCAM	991.260	BOTH	16
#
# DATA TCAM	991.310	BOTH	16
#
# DATA TCAM	991.360	BOTH	16
#
# DATA TCAM	991.410	BOTH	16
#
# DATA TCAM	991.460	BOTH	16
#
# DATA TCAM	991.510	BOTH	16
#
# DATA TCAM	991.560	BOTH	16
#
# DATA TCAM	991.610	BOTH	16
#
# DATA TCAM	991.660	BOTH	16
#
# DATA TCAM	991.710	BOTH	16
#
#
#
# DATA RCAM	990.810	BOTH	16
#
# DATA RCAM	990.860	BOTH	16
#
# DATA RCAM	990.910	BOTH	16
#
# DATA RCAM	990.960	BOTH	16
#
# DATA RCAM	991.010	BOTH	16
#
# DATA RCAM	991.060	BOTH	16
#
# DATA RCAM	991.110	BOTH	16
#
# DATA RCAM	991.160	BOTH	16
#
# DATA RCAM	991.210	BOTH	16
#
# DATA RCAM	991.260	BOTH	16
#
# DATA RCAM	991.310	BOTH	16
#
# DATA RCAM	991.360	BOTH	16
#
# DATA RCAM	991.410	BOTH	16
#
# DATA RCAM	991.460	BOTH	16
#
# DATA RCAM	991.510	BOTH	16
#
# DATA RCAM	991.560	BOTH	16
#
# DATA RCAM	991.610	BOTH	16
#
# DATA RCAM	991.660	BOTH	16
#
# DATA RCAM	991.710	BOTH	16
#
#
#
# DATA TCAM	990.810	BOTH	16
#
# DATA TCAM	990.860	BOTH	16
#
# DATA TCAM	990.910	BOTH	16
#
# DATA TCAM	990.960	BOTH	16
#
# DATA TCAM	991.010	BOTH	16
#
# DATA TCAM	991.060	BOTH	16
#
# DATA TCAM	991.110	BOTH	16
#
# DATA TCAM	991.160	BOTH	16
#
# DATA TCAM	991.210	BOTH	16
#
# DATA TCAM	991.260	BOTH	16
#
# DATA TCAM	991.310	BOTH	16
#
# DATA TCAM	991.360	BOTH	16
#
# DATA TCAM	991.410	BOTH	16
#
# DATA TCAM	991.460	BOTH	16
#
# DATA TCAM	991.510	BOTH	16
#
# DATA TCAM	991.560	BOTH	16
#
# DATA TCAM	991.610	BOTH	16
#
# DATA TCAM	991.660	BOTH	16
#
# DATA TCAM	991.710	BOTH	16
#
#
#
# DATA RCAM	990.810	BOTH	16
#
# DATA RCAM	990.860	BOTH	16
#
# DATA RCAM	990.910	BOTH	16
#
# DATA RCAM	990.960	BOTH	16
#
# DATA RCAM	991.010	BOTH	16
#
# DATA RCAM	991.060	BOTH	16
#
# DATA RCAM	991.110	BOTH	16
#
# DATA RCAM	991.160	BOTH	16
#
# DATA RCAM	991.210	BOTH	16
#
# DATA RCAM	991.260	BOTH	16
#
# DATA RCAM	991.310	BOTH	16
#
# DATA RCAM	991.360	BOTH	16
#
# DATA RCAM	991.410	BOTH	16
#
# DATA RCAM	991.460	BOTH	16
#
# DATA RCAM	991.510	BOTH	16
#
# DATA RCAM	991.560	BOTH	16
#
# DATA RCAM	991.610	BOTH	16
#
# DATA RCAM	991.660	BOTH	16
#
# DATA RCAM	991.710	BOTH	16
#
#
#
# DATA TCAM	990.810	BOTH	16
#
# DATA TCAM	990.860	BOTH	16
#
# DATA TCAM	990.910	BOTH	16
#
# DATA TCAM	990.960	BOTH	16
#
# DATA TCAM	991.010	BOTH	16
#
# DATA TCAM	991.060	BOTH	16
#
# DATA TCAM	991.110	BOTH	16
#
# DATA TCAM	991.160	BOTH	16
#
# DATA TCAM	991.210	BOTH	16
#
# DATA TCAM	991.260	BOTH	16
#
# DATA TCAM	991.310	BOTH	16
#
# DATA TCAM	991.360	BOTH	16
#
# DATA TCAM	991.410	BOTH	16
#
# DATA TCAM	991.460	BOTH	16
#
# DATA TCAM	991.510	BOTH	16
#
# DATA TCAM	991.560	BOTH	16
#
# DATA TCAM	991.610	BOTH	16
#
# DATA TCAM	991.660	BOTH	16
#
# DATA TCAM	991.710	BOTH	16
